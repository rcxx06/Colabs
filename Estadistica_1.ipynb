# %% [markdown]
# <a href="https://colab.research.google.com/github/rcxx06/Colabs/blob/main/Estadistica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
ClasePractica=pd.read_excel("clase_practica1.xlsx", sheet_name="Hoja1")

ClasePractica.tail(5)
# Out:
#           sex  edad                    niv_edu  anios_esc  hrsocup  \
# 10275  Hombre    62  Medio superior y superior         17       48
# 10276  Hombre    50  Medio superior y superior         16       25
# 10277   Mujer    21  Medio superior y superior         14       42
# 10278  Hombre    44        Secundaria completa         10       40
# 10279  Hombre    33  Medio superior y superior         17       40
#
#        ingreso_mensual num_trabajos tipo_empleo
# 10275             7740          Uno    Informal
# 10276             9000          Uno      Formal
# 10277             6450          Uno    Informal
# 10278             5590          Uno      Formal
# 10279             8000          Uno      Formal

# %%
ClasePractica.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10280 entries, 0 to 10279
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sex              10280 non-null  category
#  1   edad             10280 non-null  int64
#  2   niv_edu          10280 non-null  category
#  3   anios_esc        10280 non-null  int64
#  4   hrsocup          10280 non-null  int64
#  5   ingreso_mensual  10280 non-null  int64
#  6   num_trabajos     10280 non-null  category
#  7   tipo_empleo      10280 non-null  category
# dtypes: category(4), int64(4)
# memory usage: 362.0 KB

# %%
ClasePractica['sex']=ClasePractica['sex'].astype("category")
ClasePractica['niv_edu']=ClasePractica['sex'].astype("category")
ClasePractica['num_trabajos']=ClasePractica['sex'].astype("category")
ClasePractica['tipo_empleo']=ClasePractica['sex'].astype("category")

# %%
ClasePractica.shape
# Out:
# (10011, 8)

# %%
ClasePractica['edad'].min()
# Out:
# 12

# %%
ClasePractica['edad'].max()
# Out:
# 98

# %%
ClasePractica= ClasePractica[ClasePractica['edad']>=18]

# %%
import statistics as st

# %%
Estadisticos={"Promedio": np.mean(ClasePractica['edad']),
              "mediana": np.mean(ClasePractica['edad']),
              "moda": st.mode(ClasePractica['edad'])}

print(Estadisticos)
# Out:
# {'Promedio': np.float64(40.37948256917391), 'mediana': np.float64(40.37948256917391), 'moda': 30}

# %%
ClasePractica['sex'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='sex'>

# %%
ClasePractica.groupby('sex')['edad'].describe()
# Out:
# /tmp/ipython-input-2662309035.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ClasePractica.groupby('sex')['edad'].describe()
#          count       mean        std   min   25%   50%   75%   max
# sex
# Hombre  6149.0  40.259392  13.829024  18.0  29.0  39.0  50.0  98.0
# Mujer   3862.0  40.570689  13.390110  18.0  30.0  40.0  50.0  98.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['count'].plot(kind='hist', bins=20, title='count')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['mean'].plot(kind='hist', bins=20, title='mean')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
ClasePractica['edad'].quantile([0.25,0.75])
# Out:
# 0.25    29.0
# 0.75    50.0
# Name: edad, dtype: float64
